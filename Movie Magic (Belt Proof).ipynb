# %%
#Import lIBRARIES
import pandas as pd
import numpy as np
import os as os

# %%
# example making new folder with os

os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['basics_clean.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  'title.akas.csv.gz',
#  'title.ratings.csv.gz',
#  'title_basics.csv.gz',
#  'tmdb_api_results_2001.json']

# %% [markdown]
# # Basics Data Load & Clean

# %%
##Load Basics set and assign to DF

basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"

basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
#Assign local file to DF
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#Basics preprocessing

#Replace "\N" with np.nan
basics.replace({'\\N':np.nan}, inplace=True) 
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#Eliminate movies that are null for runtimeMinutes
basics.dropna(subset=['runtimeMinutes','genres'], inplace=True)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics['genres'].isna().sum()
# Out:
# 0

# %%
#keep only titleType==Movie
movie_filter = basics['titleType']=='movie'
movie_filter.head()

basics[movie_filter].head()
# Out:
#          tconst titleType                    primaryTitle  \
# 570   tt0000574     movie     The Story of the Kelly Gang
# 587   tt0000591     movie                The Prodigal Son
# 672   tt0000679     movie  The Fairylogue and Radio-Plays
# 1172  tt0001184     movie         Don Juan de Serrallonga
# 1273  tt0001285     movie               The Life of Moses
#
#                        originalTitle isAdult startYear endYear runtimeMinutes  \
# 570      The Story of the Kelly Gang       0      1906     NaN             70
# 587                L'enfant prodigue       0      1907     NaN             90
# 672   The Fairylogue and Radio-Plays       0      1908     NaN            120
# 1172         Don Juan de Serrallonga       0      1910     NaN             58
# 1273               The Life of Moses       0      1909     NaN             50
#
#                           genres
# 570   Action,Adventure,Biography
# 587                        Drama
# 672            Adventure,Fantasy
# 1172             Adventure,Drama
# 1273      Biography,Drama,Family

# %%
basics['runtimeMinutes'].dropna(inplace=True)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
#keep startYear 2000-2022
start_filt = basics['startYear'] >= '2000'
start_filt.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: startYear, dtype: bool

# %%
end_filt = basics['startYear']<='2022'
end_filt.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: startYear, dtype: bool

# %%
basics = basics.loc[start_filt & end_filt, :]
basics.head()
# Out:
#           tconst titleType                 primaryTitle  \
# 13082  tt0013274     movie  Istoriya grazhdanskoy voyny
# 33805  tt0034413     short           Youth Gets a Break
# 34805  tt0035423     movie               Kate & Leopold
# 39547  tt0040241     short              Color Rhapsodie
# 43551  tt0044326     short                    Abstronic
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 13082  Istoriya grazhdanskoy voyny       0      2021     NaN            133
# 33805           Youth Gets a Break       0      2001     NaN             20
# 34805               Kate & Leopold       0      2001     NaN            118
# 39547              Color Rhapsodie       0      2021     NaN              6
# 43551                    Abstronic       0      2021     NaN              6
#
#                        genres
# 13082             Documentary
# 33805                   Short
# 34805  Comedy,Fantasy,Romance
# 39547                   Short
# 43551                   Short

# %%
#Eliminate movies that include  "Documentary" in genre (see tip below)
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]
basics.head()
# Out:
#           tconst titleType        primaryTitle       originalTitle isAdult  \
# 33805  tt0034413     short  Youth Gets a Break  Youth Gets a Break       0
# 34805  tt0035423     movie      Kate & Leopold      Kate & Leopold       0
# 39547  tt0040241     short     Color Rhapsodie     Color Rhapsodie       0
# 43551  tt0044326     short           Abstronic           Abstronic       0
# 44093  tt0044879     short             Mandala             Mandala       0
#
#       startYear endYear runtimeMinutes                  genres
# 33805      2001     NaN             20                   Short
# 34805      2001     NaN            118  Comedy,Fantasy,Romance
# 39547      2021     NaN              6                   Short
# 43551      2021     NaN              6                   Short
# 44093      2021     NaN              3                   Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1417432 entries, 33805 to 8982588
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   tconst          1417432 non-null  object
#  1   titleType       1417432 non-null  object
#  2   primaryTitle    1417432 non-null  object
#  3   originalTitle   1417432 non-null  object
#  4   isAdult         1417432 non-null  object
#  5   startYear       1417432 non-null  object
#  6   endYear         21080 non-null    object
#  7   runtimeMinutes  1417432 non-null  object
#  8   genres          1417432 non-null  object
# dtypes: object(9)
# memory usage: 108.1+ MB

# %% [markdown]
# # AKAs Data Load & Clean

# %%
##Load AKAs data set and save locally 
akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"

akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

akas.to_csv("Data/title.akas.csv.gz",compression='gzip',index=False)

# %%
#Assign local file to DF
akas = pd.read_csv("Data/title.akas.csv.gz", low_memory=False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
#AKA Preprocessing
akas.replace({'\\N':np.nan}, inplace=True)

# %%
#AKA - keep only US entries. I keep breaking the main df, I'm creating a dummy
#df that I will move back once done.
dfa= akas
dfa.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %%
#Apply filter to retain only movies in US region
region_filt = dfa['region']=='US'
region_filt.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: region, dtype: bool

# %%
#Check that filtering worked...it did.  ONLY US region films are showing.
dfa[region_filt].head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
dfa = dfa.loc[region_filt, :]
dfa.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
dfa['region'].value_counts()
# Out:
# US    1326857
# Name: region, dtype: int64

# %%
#Transfer dummy set back to actual df
akas = dfa
akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
#Save new cleansed df to local csv file from earlier 
akas.to_csv("Data/title.akas.csv.gz",compression='gzip',index=False)

# %%
#Display df info as requested
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1326857 entries, 5 to 32244076
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1326857 non-null  object
#  1   ordering         1326857 non-null  int64
#  2   title            1326857 non-null  object
#  3   region           1326857 non-null  object
#  4   language         3570 non-null     object
#  5   types            1025868 non-null  object
#  6   attributes       44141 non-null    object
#  7   isOriginalTitle  1325482 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 91.1+ MB

# %% [markdown]
# # Ratings Data Load & Clean

# %%
##Load Ratings data set and assign to DF
ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"

ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

ratings.to_csv("Data/title.ratings.csv.gz",compression='gzip',index=False)

# %%
#Assign local file to DF
ratings = pd.read_csv("Data/title.ratings.csv.gz", low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1886
# 1  tt0000002            5.9       250
# 2  tt0000003            6.5      1673
# 3  tt0000004            5.8       163
# 4  tt0000005            6.2      2493

# %%
#RATINGS Preprocessing
ratings.replace({'\\N':np.nan})
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1886
# 1        tt0000002            5.9       250
# 2        tt0000003            6.5      1673
# 3        tt0000004            5.8       163
# 4        tt0000005            6.2      2493
# ...            ...            ...       ...
# 1251875  tt9916690            6.5         6
# 1251876  tt9916720            5.3       223
# 1251877  tt9916730            8.4         6
# 1251878  tt9916766            6.7        20
# 1251879  tt9916778            7.2        35
#
# [1251880 rows x 3 columns]

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251880 entries, 0 to 1251879
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1251880 non-null  object
#  1   averageRating  1251880 non-null  float64
#  2   numVotes       1251880 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.7+ MB

# %%
ratings.to_csv("Data/title.ratings.csv.gz",compression='gzip',index=False)

# %% [markdown]
# # Filtering Dataframes Upon One Another

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 33805       True
# 34805       True
# 39547       True
# 43551       True
# 44093       True
#            ...
# 8982525     True
# 8982545    False
# 8982580    False
# 8982587    False
# 8982588    False
# Name: tconst, Length: 1417432, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType           primaryTitle          originalTitle  \
# 33805    tt0034413     short     Youth Gets a Break     Youth Gets a Break
# 34805    tt0035423     movie         Kate & Leopold         Kate & Leopold
# 39547    tt0040241     short        Color Rhapsodie        Color Rhapsodie
# 43551    tt0044326     short              Abstronic              Abstronic
# 44093    tt0044879     short                Mandala                Mandala
# ...            ...       ...                    ...                    ...
# 8982281  tt9916214     short        Drown the Clown        Drown the Clown
# 8982301  tt9916254     video   Big Tit Cream Pie 32   Big Tit Cream Pie 32
# 8982347  tt9916348     video  Ancient World Exposed  Ancient World Exposed
# 8982354  tt9916362     movie                  Coven               Akelarre
# 8982525  tt9916720     short              The Nun 2              The Nun 2
#
#         isAdult startYear endYear runtimeMinutes                  genres
# 33805         0      2001     NaN             20                   Short
# 34805         0      2001     NaN            118  Comedy,Fantasy,Romance
# 39547         0      2021     NaN              6                   Short
# 43551         0      2021     NaN              6                   Short
# 44093         0      2021     NaN              3                   Short
# ...         ...       ...     ...            ...                     ...
# 8982281       0      2019     NaN              8             Drama,Short
# 8982301       1      2015     NaN            226                   Adult
# 8982347       0      2019     NaN             67                 History
# 8982354       0      2020     NaN             92           Drama,History
# 8982525       0      2019     NaN             10   Comedy,Horror,Mystery
#
# [470303 rows x 9 columns]

# %%
basics.to_csv("Data/basics_clean.csv.gz",compression='gzip',index=False)
